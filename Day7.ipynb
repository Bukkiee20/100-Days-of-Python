# %%
import random as rd
from hangman_art import stages, logo
from hangman_words import word_list



chosen_word = rd.choice(word_list)
lives = 6


display = []
for char in chosen_word:
    display.append("-")

endOfGame = False

print(logo)

while endOfGame == False:
    guess= input("Guess a letter: \n").lower()

    if guess in display:
        print(f"You have already guessed {guess}")
    
    
    for position in range(len(chosen_word)):
        char = chosen_word[position]
        if char == guess:
            display[position] = char

    print(display)
    
    if guess not in chosen_word:
        print(f"You guessed {guess}, thats not in the word, you lose a life")      
        lives -= 1
        if lives == 0:
            endOfGame = True
            print("You lose")
    
    if "-" not in display:
        endOfGame = True
        print("You win")
    print(stages[lives])
# Out:
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
#
#
# Guess a letter:
# a
# ['-', '-', '-', 'a', '-']
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Guess a letter:
# f
# ['-', '-', '-', 'a', '-']
# You guessed f, thats not in the word, you lose a life
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter:
# w
# ['-', '-', '-', 'a', '-']
# You guessed w, thats not in the word, you lose a life
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# Guess a letter:
# i
# ['-', '-', '-', 'a', '-']
# You guessed i, thats not in the word, you lose a life
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
#
# Guess a letter:
# l
# ['-', '-', '-', 'a', '-']
# You guessed l, thats not in the word, you lose a life
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# Guess a letter:
# e
# ['-', '-', '-', 'a', '-']
# You guessed e, thats not in the word, you lose a life
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# Guess a letter:
# a
# You have already guessed a
# ['-', '-', '-', 'a', '-']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# Guess a letter:
# i
# ['-', '-', '-', 'a', '-']
# You guessed i, thats not in the word, you lose a life
# You lose
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
